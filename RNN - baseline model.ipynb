# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
from time import time
from tensorflow import keras
from tensorflow.python.keras.layers import Dense,Dropout,RNN, SimpleRNN
from tensorflow.python.keras import Sequential,callbacks
from tensorflow.python.keras import utils
from keras.utils import to_categorical
from sklearn.metrics import log_loss, hinge_loss, accuracy_score, confusion_matrix
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.preprocessing import (StandardScaler, OrdinalEncoder,LabelEncoder, MinMaxScaler)

# %%
proto_values = ['tcp', 'udp', 'arp', 'ospf', 'icmp', 'igmp', 'rtp', 'ddp',
                'ipv6-frag', 'cftp', 'wsn', 'pvp', 'wb-expak', 'mtp',
                'pri-enc', 'sat-mon', 'cphb', 'sun-nd', 'iso-ip', 'xtp', 'il',
                'unas', 'mfe-nsp', '3pc', 'ipv6-route', 'idrp', 'bna', 'swipe',
                'kryptolan', 'cpnx', 'rsvp', 'wb-mon', 'vmtp', 'ib', 'dgp',
                'eigrp', 'ax.25', 'gmtp', 'pnni', 'sep', 'pgm', 'idpr-cmtp',
                'zero', 'rvd', 'mobile', 'narp', 'fc', 'pipe', 'ipcomp',
                'ipv6-no', 'sat-expak', 'ipv6-opts', 'snp', 'ipcv',
                'br-sat-mon', 'ttp', 'tcf', 'nsfnet-igp', 'sprite-rpc',
                'aes-sp3-d', 'sccopmce', 'sctp', 'qnx', 'scps', 'etherip',
                'aris', 'pim', 'compaq-peer', 'vrrp', 'iatp', 'stp',
                'l2tp', 'srp', 'sm', 'isis', 'smp', 'fire', 'ptp', 'crtp',
                'sps', 'merit-inp', 'idpr', 'skip', 'any', 'larp', 'ipip',
                'micp', 'encap', 'ifmp', 'tp++', 'a/n', 'ipv6', 'i-nlsp',
                'ipx-n-ip', 'sdrp', 'tlsp', 'gre', 'mhrp', 'ddx', 'ippc',
                'visa', 'secure-vmtp', 'uti', 'vines', 'crudp', 'iplt',
                'ggp', 'ip', 'ipnip', 'st2', 'argus', 'bbn-rcc', 'egp',
                'emcon', 'igp', 'nvp', 'pup', 'xnet', 'chaos', 'mux', 'dcn',
                'hmp', 'prm', 'trunk-1', 'xns-idp', 'leaf-1', 'leaf-2', 'rdp',
                'irtp', 'iso-tp4', 'netblt', 'trunk-2', 'cbt']

# %%
state_values = ['FIN', 'INT', 'CON', 'ECO', 'REQ', 'RST', 'PAR', 'URN', 'no',
                'ACC', 'CLO']

service_values = ['-', 'ftp', 'smtp', 'snmp', 'http', 'ftp-data',
                  'dns', 'ssh', 'radius', 'pop3', 'dhcp', 'ssl', 'irc']

attack_cat_values = ['Normal', 'Backdoor', 'Analysis', 'Fuzzers', 'Shellcode',
                     'Reconnaissance', 'Exploits', 'DoS', 'Worms', 'Generic']

# %%
def unsw_encoding(params):
   # Load csv data into dataframes without 'id' and 'Label'
    train_df = pd.read_csv('UNSW_NB15_training-set.csv').drop(['id', 'label'], axis=1)
    test_df = pd.read_csv('UNSW_NB15_testing-set.csv').drop(['id', 'label'], axis=1)
    
    def process_dataframe(df):
        # Replace attack string with an int
        for i in range(len(attack_cat_values)):
            df['attack_cat'] = df['attack_cat'].replace(
                [attack_cat_values[i]], i)

        # Assign x (inputs) and y (outputs) of the network
        y = df['attack_cat']
        x = df.drop(columns='attack_cat')

      
        # Encode categorical features as an integer array
        if params['encoder'] == 'ordinalencoder':
            x = OrdinalEncoder().fit_transform(x)
        # Encode labels with value between 0 and n_classes-1.
        elif params['encoder'] == 'labelencoder':
            x = x.apply(LabelEncoder().fit_transform)
        else:
            # Replace String features with ints
            for i in range(len(proto_values)):
                x['proto'] = x['proto'].replace(proto_values[i], i)

            for i in range(len(state_values)):
                x['state'] = x['state'].replace(state_values[i], i)

            for i in range(len(service_values)):
                x['service'] = x['service'].replace(service_values[i], i)
            # Standardize by removing the mean and scaling to unit variance
            if params['encoder'] == "standardscaler":
                x = StandardScaler().fit_transform(x)
            # Transforms features by scaling each feature to range [0, 1]
            elif params['encoder'] == "minmaxscaler01":
                x = MinMaxScaler(feature_range=(0, 1)).fit_transform(x)
            # Transforms features by scaling each feature to range [-1, 1]
            elif params['encoder'] == "minmaxscaler11":
                x = MinMaxScaler(feature_range=(-1, 1)).fit_transform(x)

        return x, y

    x_train, Y_train = process_dataframe(train_df)
    x_test, Y_test = process_dataframe(test_df)

    # Apply one-hot encoding to outputs
    y_train = to_categorical(Y_train)
    y_test = to_categorical(Y_test)

    return x_train, x_test, y_train, y_test

# %%
# training model
csv_values = ['epochs', 'acc', 'loss', 'val_acc', 'val_loss', "train_data",
              "features_nb", 'loss_fct', 'optimizer', 'activation_fct',
              'layer_nb', 'unit_nb', 'batch_size', 'dropout', 'cell_type',
              'encoder']

# %%
csv_best_res = ['param', 'value', 'min_mean_val_loss']

# %%
# epochs: Number of iteration of the training dataset
# train_data: Number of rows in training dataset
# features_nb: Number of features kept as input
# loss fct: Loss function used in training
# optimizer: Optimizer used in training
# activation_fct: Activation function used in outputs layer
# layer_nb: Number of hidden layers in the network
# unit_nb: Number of cells for each layer
# batch_size: Number of elements observed before updating weights
# dropout: Fraction of inputs randomly discarded
# cell_type: Type of cell ['RNN']
# encoder: Encoding performed (see processing files)
# dataset: Processing file to be called ['unsw']
# training_nb: Number of model to be trained with the same params
# resultstocsv: Wether to save results to csv
# resultstologs: Wether to save models and tensorboard logs
# showresults: Wether to show detailled statistics about the trained model
# shuffle: Wether to shuffle the batches sequences during training

# %%
# reference parameters
params = {'epochs': 3, 'train_data': 494021, 'features_nb': 4,
          'loss_fct': 'mse', 'optimizer': 'rmsprop',
          'activation_fct': 'sigmoid', 'layer_nb': 1, 'unit_nb': 128,
          'batch_size': 1024, 'dropout': 0.2, 'cell_type': 'RNN',
          'encoder': 'labelencoder', 'dataset': 'unsw', 'training_nb': 1,
          'resultstocsv': False, 'resultstologs': False, 'showresults': True,
          'shuffle': True}

# %%
# variable parameters
params_var = {'encoder': ['standardscaler', 'labelencoder',
                          'minmaxscaler01', 'minmaxscaler11',
                          'ordinalencoder'],
              'optimizer': ['adam', 'sgd', 'rmsprop', 'nadam', 'adamax',
                            'adadelta'],
              'activation_fct': ['sigmoid', 'softmax', 'relu', 'tanh'],
              'layer_nb': [1, 2, 3, 4],
              'unit_nb': [4, 8, 32, 64, 128, 256],
              'dropout': [0.1, 0.2, 0.3, 0.4],
              'batch_size': [512, 1024, 2048],
              }

# %%
def load_data():
    if params['dataset'] == 'unsw':
        x_train, x_test, y_train, y_test = unsw_encoding(params)
    return x_train, x_test, y_train, y_test

# %%
# method 1
# def train_model(x_train, x_test, y_train, y_test):
        
#     # Create a Sequential layer, one layer after the other
#     model = Sequential()
#     # If there is more than 1 layer, the first must return sequences
#     for _ in range(params['layer_nb']-1):
#         model.add(RNN(units=params['unit_nb'],
#                        input_shape=(x_train.shape[1:]), return_sequences=True))
#         model.add(Dropout(rate=params['dropout']))

#     # If there is only 1 layer, it must not return sequences
#     if(params['layer_nb'] == 1):
#         model.add(RNN(units=params['unit_nb'], input_shape=x_train.shape[1:]))
#         model.add(Dropout(rate=params['dropout']))
#     else:  # If there is more than 1, the following must not return sequences
#         model.add(RNN(units=params['unit_nb']))
#         model.add(Dropout(rate=params['dropout']))
#     # Outputs layer
#     model.add(Dense(units=y_train.shape[1],
#                     activation=params['activation_fct']))

#     model.compile(loss=params['loss_fct'], optimizer=params['optimizer'],
#                   metrics=['accuracy'])

#     model.summary()

#     hist = model.fit(x_train, y_train, params['batch_size'], params['epochs'],
#                      verbose=1, shuffle=params['shuffle'],
#                      validation_data=(x_test, y_test), callbacks=callbacks)

#     if params['showresults'] is True:
#         print_results(params, model, x_train, x_test, y_train, y_test)

#     return hist

# %%
x_train, x_test, y_train, y_test = load_data()
# Reshape the inputs in the accepted model format
sample = x_train.shape[0]
features = x_train.shape[1]
x_train = np.array(x_train).reshape([-1, x_train.shape[1], 1])
x_test = np.array(x_test).reshape([-1, x_test.shape[1], 1])

# %%
    # method 2
    # initialize RNN
    model = Sequential()
    #  1st RNN layer and Dropout regularization
    model.add(SimpleRNN(units = 50, activation='relu', return_sequences=True, input_shape= (x_train.shape[1],1)))
    model.add(Dropout(0.2))
     # 2nd RNN layer and Dropout regularization
    model.add(SimpleRNN(units = 50, activation='relu', return_sequences=True))
    model.add(Dropout(0.2))
    # 3rd RNN layer and Dropout regularization
    model.add(SimpleRNN(units = 50, activation='relu', return_sequences=True))
    model.add(Dropout(0.2))
    # 4th RNN layer and Dropout regularization
    model.add(SimpleRNN(units = 50))
    model.add(Dropout(0.2))
    # output layer
    model.add(Dense(units = 1))
    # compile the RNN
    model.compile(optimizer='adam', loss='mse')
    
    model.summary()
    m = model.fit(x_train, y_train, epochs=10, batch_size=32)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_15 (SimpleRNN)    (None, 42, 50)            2600
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 42, 50)            0
# _________________________________________________________________
# simple_rnn_16 (SimpleRNN)    (None, 42, 50)            5050
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 42, 50)            0
# _________________________________________________________________
# simple_rnn_17 (SimpleRNN)    (None, 42, 50)            5050
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 42, 50)            0
# _________________________________________________________________
# simple_rnn_18 (SimpleRNN)    (None, 50)                5050
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 17,801
# Trainable params: 17,801
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 5480/5480 [==============================] - ETA: 0s - loss: 0.1322 8  - ETA: 2:49 - loss: 2 - ETA: 2:48 - loss: 1.6 - ETA: 2:48 - loss: 1.62 - ETA: 2:49 - loss: 1.559 - ETA: 2: - ETA: 2:38 - loss: - ETA: 2:38 - loss: 0.911 - ETA: 2:38 - loss: - ETA: 2:38 - los - ETA: 2:42 - loss: 0.828 - ETA: 2:42 - loss - ETA: 2:41 - loss: 0. - ETA: 2:42 - loss: - ETA -  - ETA: 2:51 - lo - ETA: 2:50 - loss:  - ETA: 2:50 - lo - ETA: 2:45 - loss: 0.556 - ETA: 2:44 - loss: 0.553 - ETA: 2:43 - loss: 0.550 - ETA: 2:42 - loss: 0 - ETA: 2:39 - loss: 0. - ETA: 2:36 - loss: 0.523 - ETA: 2:35 - loss: 0.520 - ETA: 2:34 - loss: - ETA: 2:29 - loss:  - ETA: 2:25 - loss: 0.48 - ETA: 2:24 - loss: 0.483 - ETA: 2:23 - loss: 0.481 - ETA: 2:23 - loss: 0.479 - ETA: 2:22 - loss: 0.476 - ETA: 2:21 - loss: 0.474 - ETA: 2:21 - loss: 0.47 - ETA: 2:20 - loss: 0.468 - ETA: 2:19 - lo - ETA: 2:14 - loss: 0.447 - ETA: 2:13 - loss: 0.446 - ETA: 2:13 - loss: 0.44 - ETA: 2:12 - loss: 0.44 - ETA: 2:1 - ETA: 2:04 - loss: 0. - ETA: 2:03 - loss: 0.405 - ETA: 2:03 - los - ETA: 1:59 - loss: 0.39 - ETA: 1:59 - loss: 0.388 - ETA: 1:58 - loss: 0.387 - ETA: 1:58 - loss: 0.3 - ETA: 1:57 - - ETA: 1:55 - loss: 0 - ETA: 1:55 - loss: 0.3 - ETA: 1:55 - loss: 0.36 - ETA: 1:55 -  - - ETA: 1:55 - loss: 0.326 - ETA: 1:55 - loss: 0.325 - ETA: 1:54 - loss: 0.32 - ETA: 1:54 - loss: 0.322 - ETA: 1:53 - loss: 0.32 - ETA: 1:53 - loss: 0.32 - ETA: 1:52 - loss: 0.31 - ETA: 1:52 - loss: 0.316 - ETA: 1:51 - loss: 0.315 - ETA: 1:51 - loss: 0. - ETA: 1:50 - loss: 0.311 - ETA: 1:50 - los - ETA: 1:48 - loss: 0.303 - ETA: 1:47 - loss: 0 - ETA: 1:46 - loss: 0.299 - ETA: 1:46 - loss: 0.298 - ETA: 1:46 - loss: 0.29 - ETA: 1:45 - loss: 0.296 - ETA: 1:45 - los - ETA: 1:43 - loss: 0.2 - ETA: 1:42 - loss: 0.28 - ETA: 1:42 - loss: 0.28 - ETA: 1:42 - loss: 0.285 - ETA: 1:41 - loss: 0.28 - ETA: 1:41 - loss: 0.283 - ETA: 1:41 - loss: 0.28 - ETA: 1:40 - loss:  - ETA: 1:39 - loss: 0.2 - ETA: 1:38 - loss: 0. - ETA: 1:38 - loss: - ETA: 1:36 - loss: 0.270 - ETA: 1:36 - loss: 0.269 - ETA: 1:36 - loss - ETA: - ETA: 1:32 - loss: 0.256 - ETA: 1:32 - loss: 0.2 - ETA: 1:31 - loss: 0.25 - ETA: 1:31 - loss: 0.2 - ETA: 1:30 - loss: 0 - ETA: 1:30 - loss: 0 - ETA: 1:29 - loss: - ETA: 1:28 - loss: 0.245 - ETA: 1:28 - loss: 0.2 - ETA: 1:27 - loss: 0.24 - ETA: 1:27 - loss: 0.24 - ETA: 1:27 - loss:  - ETA: 1:26 - loss: 0.240 - ETA: 1:26 - loss: 0.23 - ETA: 1:25 - loss: 0.238 - ETA: 1:25 - loss: 0. - ETA: 1:24 - loss: 0.237 - ETA: 1:24 - loss: 0 - ETA: 1:24 - loss: 0.235 - ETA: 1:24 - loss: 0.2 - ETA: 1:23 - loss: 0.233 - ETA: 1:23 - loss: 0.233 - ETA: 1:23 - loss: 0.232 - ETA: 1:23 - loss: 0.232 - ETA: 1:23 - loss: - ETA: 1:22 - ETA: 1:20 - loss: 0.2 - ETA: 1:19 - loss: 0.224 - ETA: 1:19 - loss: 0.2 - ETA: 1:19 - loss: 0.2 - ETA: 1:19 - loss: 0.2 - ETA: 1:18 - loss: 0.2 - ETA: 1:18 - loss: 0.220 - ETA: 1:18 - loss: 0.22 - ETA: 1:17 - loss: 0.2 - ETA: 1:17 - loss: 0.219 - ETA: 1:17 - loss: 0.21 - ETA: 1:17 - loss: 0.218 - ETA: 1:17 - loss: 0.21 - ETA: 1:16 - loss: 0.217 - ETA: 1:16 - loss: 0 - ETA: 1:16 - loss: 0.215 - ETA: 1:15 - loss: 0.215 - ETA: 1:15 - loss: 0.215 - ETA: 1:15 - loss: 0.214 - ETA: 1:15 - loss: 0.214 - ETA: 1:15 - loss: 0.2 - ETA: 1:15 - loss: 0 - ETA: 1:14 - loss: 0.21 - ETA: 1:14 - los - ETA: 1:13 - loss: - ETA: 1:12 - loss: 0.208 - ETA: 1:12 - loss: 0. - ETA: 1:12 - loss: 0.2 - ETA: 1:12 - loss: 0.207 - ETA: 1:12 - loss: 0.2 - ETA: 1:11 - loss: 0. - ETA: 1:11  - ETA: 1:08 - loss: 0.19 - ETA: 1: - ETA: 1:06 - loss: 0.19 - ETA: 1:06 - loss: 0.1 - ETA: 1:06 - loss: 0.19 - ETA: 1:06 - loss: 0.195 - ETA: 1:06 - los - ETA: 1:05 -  - ETA: 1:04 - loss - ETA: 1:04 - loss: 0.  - ETA: 1 - ETA: 1:00 - loss: 0. - ETA: 59s - loss: 0 - - ETA: 58s  - ETA: 58s - loss - ETA: 58s - loss: 0. - ETA: 56s -  - ETA: 56 - ETA: 55s - loss - ETA: 55s -  - ETA: 55s - loss:  - ETA: 55s - loss:  - ETA: 54s - loss: 0.17 - ETA:  - ETA: 54s - loss: 0.17 - ETA: 54s - loss: 0. - ETA: 53s - loss:  - ETA: 53 - ETA: 53s - lo - ETA: 52s - loss: 0. - ETA: 52 ...
# Epoch 2/10
# 5235/5480 [===========================>..] - ETA: 4s - loss: 0.0900  - ETA - ETA: 1:31 - loss: - ETA: 1:30 - loss: 0.090 - ETA: 1:30 - loss:  - ETA: 1:30 - loss - ETA: 1:30 - loss: 0. - ETA: 1:30 - loss: - ETA: 1:30 - loss: 0.0 - ETA: 1:30 - los - ETA: 1:30 - loss: 0.0 - ETA: 1:30 - loss: 0.0 - ETA: 1:30 - loss: 0.090 - ETA: 1:3 - ETA: 1:28 - loss:  - ETA: 1:28 - loss: 0 - ETA: 1:28 - loss: 0. - ETA: 1:27 - loss: 0 - ETA: 1:27 - loss: 0. - ETA: 1:27 - loss: 0 - ETA: 1:26 - loss: 0 - ETA: 1:26 - loss: 0. - ETA: 1:26 - ETA: 1:25 -  - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: 0.09 - ETA: 1:24 - loss:  - ETA: 1:23 - los - ETA:  - ETA: 1:21 - ETA: 1:20 -  - ETA: 1:20 - loss: - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.09 - ETA: 1:19 - loss:  - ETA: 1:19 - loss: 0.09 - ETA: 1:19 - loss: 0. - ETA: 1:19 - lo - ETA: 1:18 - loss: 0. - ETA: 1:18 - loss: 0.09 - E - ETA: 1:17 - loss: 0.090 - ETA: 1:16 - loss - ETA: 1:16 - loss: 0.0 - ETA: 1:16 - loss: 0. - ET - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0.0 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss:  - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: - ETA: 1:13 - loss: 0 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.0 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.09 - E - ETA: 1:10 - loss: 0.0 - ETA: 1:09 - loss: 0 - ETA: 1:08 - lo - ETA: 1:08 - loss: 0. - ETA: 1:07 - loss: 0.090 - ETA: 1:07 - loss: 0 - ETA: 1:07 - loss: 0.0 - ETA: 1:07 - loss: 0.090 - ETA: 1:07 - loss: 0.0 - ETA: 1:07 - loss:  - ETA: 1:05  - ETA: 1:04 - loss:  - ETA: 1:03 - loss: 0.0 - ETA: 1:03 - loss: 0 - ETA: 1:03 - loss: 0. - ETA: 1:02 - loss: 0.090 - ETA: 1:02 - loss: 0.090 - ETA: 1:02 - loss: 0. - ETA: 1:02 - l - ETA: 1:01 - los - ETA: 1:01 - loss: 0.0 - ETA: 1:01 - l - ETA: 1:00 - loss:  - ETA: 1:00 - loss: - ETA: 1:00 - ETA: 58 - ETA: 56s - loss:  - ETA: 55s - loss: 0. - E - ETA: 54s  - ETA: 54s - lo - ETA: 54s - loss: 0.09 - ETA: 54s - loss: 0. - ETA: 54s - lo - ETA: 53s - lo - ETA: 53s - loss: 0. - ETA: 53s - loss:  - ETA: 52s - loss:  - ETA: 52s - loss: 0.09 - ETA - ETA: 51s -  - ETA: 51s - loss: 0.09 - ETA: 51s - loss:  - ETA: 51s - loss: 0. - ETA: 51s - loss: 0.09 - ETA: 51s - loss - ETA: 50s - loss: 0.09 - ETA: 50s - loss: 0.09 - ETA: 50s - loss: 0. - ETA: 50s - loss: 0.09 - ETA:  - ETA: 49s - loss - ETA: 49s - loss - ETA: 49 - ETA: 48s - loss: 0. - ETA: 48s - loss: 0.09 - ETA: 48s - loss:  - ETA: 48s - loss: 0.09 - ETA: 48s - loss: 0. - ETA: 48s - loss:  - ETA: 47s - loss: 0.09 - ETA: 47s - loss: 0.09 - ETA: 47s - loss: 0.09 - E - ETA - ETA: 46s - loss: 0.09 - ETA: 46s - loss: 0. - ETA: 45s - loss: 0.09 - ETA: 45s - loss: 0.09 - ETA: 45s - loss: 0.09 - ETA: 45s - loss: 0.09 - ETA: 45s - loss - ETA: 45s - loss: 0.09 - ETA: 45s - loss:  - ETA: 45s - loss: 0.09 - ETA: 44s - lo - ETA: 44s - loss - ETA: 44s -  - ETA: 43s - loss: 0.09 - ETA: 43s - loss: 0. - ETA: 43s -  - ETA: 43 - ETA: 42s - loss: 0.09 - ETA: 42s - loss: 0.09 - ETA: 42s - loss - ETA: 42s - loss: 0.09 - ETA: 42 - ETA: 41s - loss: 0.09 - ETA: 41s - loss: 0.09 - ETA: 41s - loss: 0.09 - ETA: 41s - loss: 0.09 - ETA: 41s - loss: 0.09 - ETA: 41s -  - ETA: 40s - loss: 0. - ETA: 40s - loss: 0.09 - ETA: 40s -  - ETA: 40s - loss: 0.09 - ETA: 40s - loss: 0.09 - ETA: 40s - loss: 0.09 - ETA: 39s - loss: 0.09 - ETA: 39s - loss: 0. - ETA: 39s - lo - ETA: 39s - loss: 0.09 - ETA: 39s - loss: 0. - ETA: 39s - loss: 0.09 - ETA: 39s - lo - ETA: 38s - loss: 0.09 - ETA: 38s - loss: 0.09 - ETA: 38s - loss: 0.09 - ETA: 38s - loss: 0.09 - ETA: 38s - loss: 0.09 - ETA: 38s - loss - ETA: 38s - loss: 0. - ETA: 38s - loss: 0. - ETA: 37s - loss: 0. - ETA: 37s - lo - ETA: 37s - loss: 0.09 - ETA: 37s - loss: 0.09 - ETA: 37s - loss: 0. - ETA: 37s - loss: 0.09 - ETA: 37s - loss: 0.09 - ETA: 36s - loss: 0.09 - ETA: 36s - loss: 0.09 - ETA: 36s - loss: 0. - ETA: 36s - loss:  - ETA: 36s - loss: 0.09 - ETA: 36s - loss: 0. - ETA: 36s - loss: 0.09 - ETA: 36s - loss: 0. - ETA: 36s - loss: 0.09 - ETA: 35s - loss: 0.09 - ETA: 35s - loss:  - ETA: 35s -  - ETA: 35s - loss - ETA: 35s  ...
# Epoch 3/10
# 3449/5480 [=================>............] - ETA: 31s - loss: 0.09000- ETA: 1:23 - loss: 0.09 - ETA: 1:22 - loss: 0.090 - ETA: 1:22 - loss: 0 - ETA: 1:22 - loss: 0.09 - ETA: 1:22 - loss: 0.090 - ETA: 1:21 - loss:  - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0. - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.09 - ETA: 1:21 - loss: 0.0 - ETA: 1:20 - loss: 0 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.09 - ETA: 1:20 - loss: 0 - ETA: 1:20 - loss: - ETA: 1:19 - loss:  - ETA: 1:19 - loss: 0. - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.090 - ETA: 1:18 - loss: 0 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0. - ETA: 1:18 - loss: 0.09 - ETA: 1:18 - loss:  - ETA: 1:17 - loss: 0.09 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0. - ETA: 1:17 - loss: 0 - ETA: 1:17 - loss: - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.09 - ETA: 1:16 - loss: 0.09 - ETA: 1:15 - loss:  - ETA: 1:15 - loss: 0.09 - ETA: 1:15 - loss: 0.09 - ETA: 1:15 - loss:  - ETA: 1:15 - loss: 0.090 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0 - ETA: 1:14 - loss: 0.09 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss:  - ETA: 1:14 - loss: 0.09 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0. - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0 - ETA: 1:13 - loss: 0. - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss:  - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0. - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss:  - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.09 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:10 - loss: 0. - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0. - ETA: 1:10 - loss: 0.09 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: - ETA: 1:09 - loss: 0.09 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0. - ETA: 1:08 - loss: 0.090 - ETA: 1:08 - loss: 0.09 - ETA: 1:08 - loss: 0.090 - ETA: 1:08 - loss: 0.0 - ETA: 1:08 - loss: 0.09 - ETA: 1:08 - loss: 0. - ETA: 1:08 - loss: 0.090 - ETA: 1:08 - loss: 0.09 - ETA: 1:07 - loss: 0 - ETA: 1:07 - loss: 0.090 - ETA: 1:07 - loss: 0.09 - ETA: 1:07 - loss: 0.090 - ETA: 1:07 - loss: 0 - ETA: 1:07 - loss: 0.090 - ETA: 1:07 - loss: 0.09 - ETA: 1:0 - ETA: 1:06 - loss: 0.09 - ETA: 1:06 - loss: 0.090 - ETA: 1:06 - loss: 0.090 - ETA: 1:05 - loss: 0 - ETA: 1:05 - loss: 0 - ETA: 1:05 - loss: 0.090 - ETA: 1:05 - loss: 0.090 - ETA: 1:05 - loss: 0.090 - ETA: 1:05 - loss: 0.090 - ETA: 1:05 - loss: 0 - ETA: 1:04 - loss: 0.090 - ETA: 1:04 - loss: 0.09 - ETA: 1:04 - loss: 0.090 - ETA: 1:04 - loss: 0.090 - ETA: 1:04 - loss: 0.090 - ETA: 1:04 - loss: 0.090 - ETA: 1:04 - loss: 0.090 - ETA: 1:04 - loss: 0.090 - ETA: 1:04 - loss: 0.090 - ETA: 1:04 - loss: 0. - ETA: 1:03 - loss: 0.090 - ETA: 1:03 - loss: 0.090 - ETA: 1:03 - loss: 0 - ETA: 1:03 - loss: 0.09 - ETA: 1:03 - loss: 0.090 - ETA: 1:03 - loss: 0. - ETA: 1:03 - loss: 0.09 - ETA: 1:02 - loss: 0.09 - ETA: 1:02 - loss: 0. - ETA: 1:02 - loss: 0.090 - ETA: 1:02 - loss: 0.09 - ETA: 1:02 - loss: 0.09 - ETA: 1:02 - loss: 0 - ETA: 1:01 - loss: 0.09 - ETA: 1:01 - loss: 0.090 - ETA: 1:01 - loss: 0.0 - ETA: 1:01 - loss: 0.090 - ETA: 1:01 - loss: 0.090 - ETA: 1:01 - loss: 0 - ETA: 1:01 - loss: 0 - ETA: 1:00 - lo - ETA: 1:00 - loss: 0. - ETA: 1:00 - loss: 0.0 - ETA: 1:00 - loss: 0.090 - ETA: 1:00 - loss: 0.09 - ETA: 59s - l - ETA: 59s - loss: 0.09 - ETA: 59s - loss: 0.09 - ETA: 59s - loss: 0.09 - ETA: 59s - loss: 0.09 - ETA: 59s - loss: 0.09 - ETA: 59s - loss: 0.09 - ETA: 59s - loss: 0. - ETA: 59s - ...
# Epoch 4/10
# 3722/5480 [===================>..........] - ETA: 28s - loss: 0.0900 - ETA: 1:24 - loss: 0. - ETA: 1:25 - loss:  - ETA: 1:25 - loss: 0.090 - ETA: 1:25 - loss: 0.090 - ETA: 1:25 - loss: 0.0 - ETA: 1:25 - loss: 0.090 - ETA: 1:25 - loss: 0.090 - ETA: 1:25 - loss: 0.0 - ETA: 1:25 - loss: 0.090 - ETA: 1:25 - loss: 0.09 - ETA: 1:24 - loss: 0. - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss:  - ETA: 1:26 - loss: 0 - ETA: 1:26 - loss: 0.090 - ETA: 1:26 - loss: 0.090 - ETA: 1:26 - loss: 0. - ETA: 1:26 - loss: 0.0 - ETA: 1:26 - loss: 0 - ETA: 1:27 - lo - ETA:  - ETA: 1:33 - l - ETA: 1:32 - loss: 0. - ETA: 1:32 - loss: - ETA: 1:31 - loss: 0.09 - ETA: 1:3 - ETA: 1:30 - loss: 0.090 - ETA: 1:30 - loss: 0.090 - ETA: 1:29 - loss: - ETA: 1:28 - loss: 0.09 - ETA: 1:28 - loss: 0.090 - ETA: 1:28 - loss: 0.090 - ETA: 1:28 -  - ETA: 1:27 - loss: 0.090 - ETA: 1:27 - lo - ETA: 1:26 - - ETA: 1:26 - loss: - ETA: 1:25 - loss: 0.09 - ETA: 1:25 - loss:  - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: - ETA: 1:23 - loss: 0.09 - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0.090 - ETA: 1:22 - loss: 0 - ETA: 1:22 - loss: 0. - ETA: 1:21 - loss: 0.0 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.09 - ETA: 1:21 - los - ETA: 1:20 - loss: 0 - ETA: 1:20 - loss: 0.090 - ETA: 1:19 - loss: 0. - ETA: 1:19 - loss: 0.09 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0. - ETA: 1:17 - loss:  - ETA: 1:17 - loss:  - ETA: 1:17 - loss: 0. - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0. - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0.09 - ETA: 1:15 - loss:  - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0.09 - ETA: 1:14 - loss: 0.0 - ETA: 1:14 - loss: 0. - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.09 - ETA: 1:13 - loss: 0.0 - ETA: 1:13 - loss: 0.09 - ETA: 1:13 - loss: 0.09 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0. - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss:  - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0. - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.09 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:10 - loss: 0.09 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0.09 - ETA: 1:10 - loss: 0.09 - ETA: 1:10 - loss: 0.09 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0.0 - ETA: 1:09 - loss: 0.0 - ETA: 1:09 - loss: 0.09 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.09 - ETA: 1:09 - loss: 0 - ETA: 1:08 - los - ETA: 1:07 - loss: 0 - ETA: 1:07 - loss: 0.09 - ETA: 1:07 - loss: 0.09 - ETA: 1:07 - loss: 0 - ETA: 1:07 - loss: 0.090 - ETA: 1:07 - loss: - ETA: 1:06 - loss:  - ETA: 1:06 - loss: 0 - ETA: 1:06 - loss: 0.090 - ETA: 1:06 - loss: 0 - ETA: 1:05 - loss: 0.090 - ETA: 1:05 - loss: 0.090 - ETA: 1:05 - loss: 0. - ETA: 1:05 - loss: 0.090 - ETA: 1:05 - loss: 0.09 - ETA: 1:05 - loss: 0.09 - ETA: 1:04 - loss: 0. - ETA: 1:04 - loss: 0.090 - ETA: 1:04 - loss: 0.09 - ETA: 1:04 - loss: 0.090 - ETA: 1:04 - loss: 0 - ETA: 1:04 - loss: 0.09 - ETA: 1:04 - loss: 0.09 - ETA: 1:04 - loss: 0.090 - ETA: 1:03 - loss: 0.090 - ETA: 1:03 - loss: 0. - ETA: 1:03 - loss: 0.0 - ETA: 1:03 - loss: 0.090 - ETA: 1:03 - loss: 0.090 - ETA: 1:03 - loss: 0. - ETA: 1:02 - loss: 0 - ETA: 1:02 - loss: 0.09 - ETA: 1:02 - loss: 0.090 - ETA: 1:02 - loss: 0.090 - ETA: 1:02 - loss: 0.090 - ETA: 1:02 - loss: 0.090 - ETA: 1:01 - loss: 0.0 - ETA: 1:01 - loss: 0.0 - ETA: 1:01 - loss: 0. - ETA: 1:01 - los - ETA: 1:00 - loss: 0 - ETA: 1:00 - l - ETA: 59s - lo - ETA: 59s -  - ETA: 59s - lo - ETA: 59 - ETA: 58s - loss: 0.09 - ETA: 58s - loss: 0. - ETA: 58s - loss:  - ETA: 58s  - ETA:  ...
# Epoch 5/10
# 2646/5480 [=============>................] - ETA: 44s - loss: 0.0900 - ETA: 1:32 - loss: 0.090 - ETA: 1:30 - loss: 0.090 - ETA: 1:29 - loss: 0.090 - ETA: 1:28 - loss: 0.0 - ETA: 1:27 - loss: 0.090 - ETA: 1:27 - loss: 0 - ETA: 1:26 - loss: 0.090 - ETA: 1:26 - loss: 0.090 - ETA: 1:26 - loss:  - ETA: 1:26 - loss: - ETA: 1:26 - loss: 0.090 - ETA: 1:26 - loss: 0.090 - ETA: 1:26 - loss: 0.09 - ETA: 1:26 - loss: 0.09 - ETA: 1:25 - loss: 0.090 - ETA: 1:25 - loss: 0.09 - ETA: 1:25 - loss: 0.09 - ETA: 1:25 - loss: 0.09 - ETA: 1:25 - loss: 0.090 - ETA: 1:24 - loss:  - ETA: 1:24 - loss: 0.09 - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: 0.090 - ETA: 1:23 - loss: 0.09 - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0.09 - ETA: 1:23 - loss: 0.0 - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0 - ETA: 1:22 - loss: 0 - ETA: 1:22 - loss: 0.090 - ETA: 1:22 - loss: 0.090 - ETA: 1:22 - loss: 0.09 - ETA: 1:22 - loss: 0.09 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.0 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.09 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0. - ETA: 1:20 - loss: 0.0 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.09 - ETA: 1:19 - loss: 0.09 - ETA: 1:19 - loss: 0.09 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0. - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.0 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:17 - loss: 0.09 - ETA: 1:17 - loss: 0.0 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0.09 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0.0 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.09 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.09 - ETA: 1:16 - loss: 0.09 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:15 - loss: 0.09 - ETA: 1:15 - loss: 0.09 - ETA: 1:15 - loss: 0. - ETA: 1:15 - loss: 0.09 - ETA: 1:15 - loss: 0.0 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0.09 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0.09 - ETA: 1:14 - loss: 0.09 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0.09 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0.09 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0.090 - ETA: 1:13 - loss: 0.09 - ETA: 1:13 - loss: 0. - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.09 - ETA: 1:13 - loss: 0 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.09 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.09 - ETA: 1:11 - loss: 0.0 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.0 - ETA: 1:11 - loss: 0.0 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0.09 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0.090 ...
# Epoch 6/10
# 3465/5480 [=================>............] - ETA: 33s - loss: 0.0900 - ETA: 1:34 - loss: 0.0 - ETA: 1:32 - loss: 0.0 - ETA: 1:30 - loss: 0.090 - ETA: 1:30 - loss: 0 - ETA: 1:33 - loss: 0.090 - ETA: 1:34 -  - ETA: 1:38 - loss - ETA: 1:42 - loss - ETA: 1:44 - loss: - ETA: 1:45 - los - ETA: 1:42 - loss: 0. - ETA: 1:41 - loss: 0. - ETA: 1:40 - loss: 0.0 - ETA: 1:40 - loss - ETA: 1:40 - loss: 0.09 - ETA: 1:40 - loss: 0.0 - ETA: 1:40 - loss: 0.090 - ETA: 1:41 - loss: 0.09 - ETA: 1:41 - loss: - ETA: 1:41 - loss: 0.09 - ETA: 1:41 - loss: 0.09 - ETA: 1:41 - loss: 0.090 - ETA: 1:41 -  - ETA: 1:40 - loss: 0 - ETA: 1:39 - loss: 0. - ETA: 1:38 - loss: 0.09 - ETA: 1:38 - loss: 0.09 - ETA: 1:37 - loss: 0.090 - ETA: 1:37 - loss: 0.09 - ETA: 1:37 - loss: 0.090 - ETA: 1:36 - loss: 0.09 - ETA: 1:36 - loss: 0.09 - ETA: 1:36 - loss: 0.090 - ETA: 1:35 - loss: 0.090 - ETA: 1:35 - loss: 0.090 - ETA: 1:35 - loss: 0. - ETA: 1:34 - loss: 0. - ETA: 1:34 - loss: 0.090 - ETA: 1:34 - loss: 0.090 - ETA: 1:33 - loss - ETA: 1:32 - loss: 0.090 - ETA: 1:32 - loss: 0.090 - ETA: 1:32 - loss: 0.090 - ETA: 1:31 - loss: 0.090 - ETA: 1:31 - loss: 0.090 - ETA: 1:31 - loss: 0. - ETA: 1:31 - loss: 0.090 - ETA: 1:30 - loss: 0.090 - ETA: 1:30 - loss: 0.090 - ETA: 1:30 - loss: 0.090 - ETA: 1:30 - loss: 0.090 - ETA: 1:30 - loss: 0.090 - ETA: 1:30 - loss:  - ETA: 1:29 - loss: 0.090 - ETA: 1:28 - loss: 0. - ETA: 1:28 - lo - ETA: 1:27 - loss: 0.090 - ETA: 1:27 - loss: 0.090 - ETA: 1:27 - loss: 0.090 - ETA: 1:27 - loss: 0.090 - ETA: 1:26 - loss: 0.09 - ETA: 1:26 - loss: 0.09 - ETA: 1:26 - loss: 0.09 - ETA: 1:26 - loss: 0 - ETA: 1:25 - loss: 0 - ETA: 1:25 - loss: 0.0 - ETA: 1:24 - loss:  - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: 0.09 - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0.0 - ETA: 1:23 - loss:  - ETA: 1:23 - l - ETA: 1:22 - loss: 0.090 - ETA: 1:22 - loss: 0.0 - ETA: 1:22 - loss: 0.09 - ETA: 1:22 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.0 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0 - ETA: 1:20 - loss: 0.09 - ETA: 1:20 - loss: 0. - ETA: 1:20 - loss: 0.09 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss:  - ETA: 1:19 - loss: 0.0 - ETA: 1:18 -  - ETA: 1:17 - loss:  - ETA: 1:17 - loss: 0.0 - ETA: 1:17 - loss: 0 - ETA: 1:16 - loss - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:15 - loss: 0.09 - ETA: 1:15 - loss: 0.09 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss:  - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0. - ETA: 1:13 - loss: 0.09 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss - ETA: 1:12 - loss: 0.09 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.09 - ETA: 1:12 - loss: 0.0 - ETA: 1:11 - loss: 0.09 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.09 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0.09 - ETA: 1:10 - loss: 0. - ETA: 1:10 - loss: 0. - ETA: 1:10 - loss: 0.0 - ETA: 1:09 - loss: 0.09 - ETA: 1:09 - loss: 0. - ETA: 1:09 - loss: 0.09 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: - ETA: 1:08 - loss: 0.090 - ETA: 1:08 - loss: 0. - ETA: 1:08 - loss: 0.09 - ETA: 1:08 - loss: 0.09 - ETA: 1:07 - loss: 0. - ETA: 1:07 - loss: 0 - ETA: 1:07 - loss:  - ETA: 1:06 - loss: - ETA: 1:06 - loss: - ETA: 1:05 - loss: 0.09 - ETA: 1:05 - loss: 0.090 - ETA: 1:05 - loss: 0.0 - ETA: 1:05 - loss: 0. - ETA: 1:05 - loss: 0. - ETA: 1:04 - loss: 0.090 - ETA: 1:04 - loss: 0.090 - ETA: 1:04 - loss: 0.090 - ETA: 1:04 - loss:  - ETA: 1:04 - loss: 0 - ETA: 1:03 - loss: 0.090 - ETA: 1:03 - loss: 0.090 - ETA: 1:03 - loss: 0.090 - ETA: 1:03 - loss: 0.090 - ETA: 1:03 - loss - ETA: 1:03 - loss: 0.09 - ETA: 1:02 - loss: 0.090 - ETA: 1:02 - loss ...
# Epoch 7/10
# 2627/5480 [=============>................] - ETA: 45s - loss: 0.09000- ETA: 1:25 - loss: 0.0 - ETA: 1:26 - loss: 0.090 - ETA: 1:26 - loss: 0.090 - ETA: 1:26 - loss: 0.09 - ETA: 1:26 - loss: 0.090 - ETA: 1:26 - loss: 0.09 - ETA: 1:26 - loss: 0.09 - ETA: 1:26 - loss: 0.090 - ETA: 1:26 - loss: 0.090 - ETA: 1:26 - los - ETA: 1:26 - loss: 0.090 - ETA: 1:26 - loss - ETA: 1:26 - loss: 0.090 - ETA: 1:26 - loss: 0 - ETA: 1:25 - loss: 0.0 - ETA: 1:25 - loss: 0.0 - ETA: 1:25 - loss: - ETA: 1:25 - loss: 0.09 - ETA: 1:25 - loss: 0.090 - ETA: 1:25 - loss: 0.090 - ETA: 1:25 - loss: 0 - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: 0. - ETA: 1:24 - loss: 0. - ETA: 1:24 - loss: 0.09 - ETA: 1:23 - loss: 0.0 - ETA: 1:23 - loss: 0.0 - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0.0 - ETA: 1:23 - loss: 0.090 - ETA: 1:22 - loss: 0.09 - ETA: 1:22 - loss: 0.090 - ETA: 1:22 - loss: 0.090 - ETA: 1:22 - loss: 0 - ETA: 1:22 - loss: 0.090 - ETA: 1:22 - loss: 0.090 - ETA: 1:22 - loss: 0.090 - ETA: 1:21 - loss: 0. - ETA: 1:21 - loss: 0. - ETA: 1:21 - loss: 0.09 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.09 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0 - ETA: 1:19 - loss: 0.0 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.0 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.09 - ETA: 1:19 - loss: 0.090 - ETA: 1:18 - loss: - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.09 - ETA: 1:18 - loss: 0.09 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.09 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0.09 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: - ETA: 1:17 - loss: 0.0 - ETA: 1:17 - loss: 0.090 - ETA: 1:16 - loss: 0.09 - ETA: 1:16 - loss: 0.09 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0. - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.0 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - l - ETA: 1:15 - loss: 0. - ETA: 1:14 - loss:  - ETA: 1:14 - loss: 0.09 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0.0 - ETA: 1:14 - loss: - ETA: 1:13 - lo - ETA: 1:13 - loss: 0.09 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 -  - ETA: 1:13 - loss: 0 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0. - ETA: 1:12 - loss: 0. - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:11 - loss: 0.09 - ETA: 1:11 - loss: 0.09 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.0 - ETA: 1:11 - loss: 0. - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.09 - ETA: 1:10 - loss: 0.09 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0.09 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - los - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.09 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.09 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.09 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:08 - loss: 0.090 - ETA: 1:08 - loss: 0.090 - ETA: 1:08 - loss: 0 - ETA: 1:08 - loss: 0. - ETA: 1:08 - loss: 0. - ETA: 1:07 - loss: 0.09 - ETA: 1:07 - loss: 0.09 - ETA: 1:07 - loss: 0.090 - ETA: 1:07 - loss: 0.09 - ETA: 1:07 - loss: 0.090 - ETA: 1:07 - loss: 0.09 - ETA: 1:07 - loss: 0.09 - ETA: 1:07 - loss: 0.090 - ETA: 1:07 - loss: 0.090 - ETA: 1:06 - loss: 0.09 - ETA: 1:06 - loss: 0.090 - ETA: 1:06 - loss: 0.090 - ETA: 1:06 - loss: 0.090 - ETA: 1:06 - loss: 0.090 - ETA: 1:06 - loss: 0.0 - ETA: 1:06 - loss: 0.0 - ETA: 1:06 - loss: 0.09 - ETA: 1:06 - loss: 0.090 - ETA: 1:05 - loss: 0.090 - ETA: 1:05 - loss: 0.090 - ETA: 1:05 - loss: 0.090 - ETA: 1:05 - loss: 0.090 - ETA: 1:05 - loss: 0.090 - ETA: 1:05 - loss: 0.090 - ETA: 1:05 - loss: 0. ...
# Epoch 8/10
# 2333/5480 [===========>..................] - ETA: 49s - loss: 0.0900 - ETA: 1:27 - loss: 0.090 - ETA: 1:27 - loss:  - ETA: 1:27 - loss: 0.090 - ETA: 1:27 - loss: 0.09 - ETA: 1:27 - loss: 0.090 - ETA: 1:26 - loss: 0.090 - ETA: 1:26 - loss: 0.09 - ETA: 1:26 - loss: 0.09 - ETA: 1:26 - loss: 0.09 - ETA: 1:26 - loss: 0.090 - ETA: 1:25 - loss: 0.090 - ETA: 1:25 - loss: 0.090 - ETA: 1:25 - loss: 0.09 - ETA: 1:25 - loss - ETA: 1:24 - loss: 0.0 - ETA: 1:25 - loss: 0.090 - ETA: 1:25 - loss: 0.09 - ETA: 1:25 - loss: 0.0 - ETA: 1:25 -  - ETA: 1:25 - loss: 0. - ETA: 1:25 - loss: 0.09 - ETA: 1:25 - loss: - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: 0.09 - ETA: 1:24 - loss: 0. - ETA: 1:23 - loss: 0.09 - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0.09 - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0 - ETA: 1:22 - loss: 0.090 - ETA: 1:22 - loss: 0.090 - ETA: 1:22 - loss: 0.09 - ETA: 1:22 - loss: 0.09 - ETA: 1:22 - loss: 0.090 - ETA: 1:22 - loss: 0.090 - ETA: 1:22 - loss: 0.09 - ETA: 1:22 - loss: 0.090 - ETA: 1:21 - loss: 0.09 - ETA: 1:21 - loss:  - ETA: 1:21 - loss - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.09 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.09 - ETA: 1:20 - loss: 0.09 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.0 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.09 - ETA: 1:19 - loss: 0.09 - ETA: 1:19 - loss: 0.090 - ETA: 1:18 - loss: 0 - ETA: 1:18 - loss: 0.09 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0. - ETA: 1:18 - loss: 0.09 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0. - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0.09 - ETA: 1:17 - loss: 0.0 - ETA: 1:16 - loss: 0. - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.09 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0 - ETA: 1:15 - loss: 0.09 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0. - ETA: 1:15 - loss: 0.09 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0.09 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0.09 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0. - ETA: 1:14 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.0 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.09 - ETA: 1:12 - loss: 0.09 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.09 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.09 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.09 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.0 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.0 - ETA: 1:11 - loss: 0.090 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0.09 - ETA: 1:10 - loss: 0.0 - ETA: 1:10 - loss: 0. - ETA: 1:10 - loss: 0.0 - ETA: 1:09 - loss: 0.09 - ETA: 1:09 - loss: 0.0 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.09 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:08 - loss: 0.09 - ETA: 1 ...
# Epoch 9/10
# 2453/5480 [============>.................] - ETA: 48s - loss: 0.09000- ETA: 1:23 - loss: 0.0 - ETA: 1:23 - loss: 0.090 - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: 0.09 - ETA: 1:25 - loss: 0.0 - ETA: 1:25 - loss: 0.09 - ETA: 1:24 - loss: 0. - ETA: 1:25 - loss: 0.090 - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: 0.090 - ETA: 1:24 - loss: 0.0 - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0.09 - ETA: 1:23 - loss: - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0.09 - ETA: 1:22 - loss: 0.0 - ETA: 1:22 - loss: 0. - ETA: 1:22 - loss: 0.090 - ETA: 1:22 - loss: 0.09 - ETA: 1:22 - loss: 0.09 - ETA: 1:22 - loss: 0.090 - ETA: 1:22 - loss: 0.090 - ETA: 1:21 - loss: 0.09 - ETA: 1:21 - loss: 0. - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss - ETA: 1:20 - loss: 0. - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.09 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.09 - ETA: 1:20 - loss: 0 - ETA: 1:19 - loss: 0 - ETA: 1:19 - loss: - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.09 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.0 - ETA: 1:18 - loss: 0.09 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0.09 - ETA: 1:17 - loss:  - ETA: 1:17 - loss: 0.0 - ETA: 1:17 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss:  - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.09 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.0 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0.09 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0. - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0.09 - ETA: 1:15 - loss:  - ETA: 1:14 - loss: 0 - ETA: 1:14 - loss: 0.09 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0.090 - ETA: 1:14 - loss: 0.09 - ETA: 1:14 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:13 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.0 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.09 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.09 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:11 - loss: 0 - ETA: 1:11 - loss: 0.0 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 - loss: 0.090 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0. - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0.09 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0.090 - ETA: 1:10 - loss: 0. - ETA: 1:09 - loss: 0.0 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0.09 - ETA: 1:08 - loss: 0.090 - ETA: 1:08 - loss: 0.090 - ETA: 1:08 - loss: 0.090 - ETA: 1:08 - loss: 0 ...
# Epoch 10/10
# 3517/5480 [==================>...........] - ETA: 31s - loss: 0.09000- ETA: 1:29 - loss: 0.090 - ETA: 1:29 - lo - ETA: 1:30 - lo - ETA: 1:29 - loss: 0.090 - ETA: 1:29 - l - ETA: 1:27 - loss: 0. - ETA: 1:27 - loss: 0.09 - ETA: 1:27 - loss - ETA: 1:27 - los - ETA: 1:26 - loss: 0.090 - ETA: 1:26 - loss: 0.0 - ETA: 1:26 - loss: 0.090 - ETA: 1:26 - loss: 0.090 - ETA: 1:25 - loss: 0.0 - ETA: 1:25 - loss: 0. - ETA: 1:25 - loss: 0. - ETA: 1:24 - loss: 0.09 - ETA: 1:24 - loss: 0.09 - ETA: 1:24 - loss: 0.09 - ETA: 1:24 - loss: 0.09 - ETA: 1:24 - loss: 0 - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0.090 - ETA: 1:23 - loss: 0.09 - ETA: 1:23 - loss: 0. - ETA: 1:22 - loss: 0.0 - ETA: 1:22 - loss: 0.09 - ETA: 1:22 - loss: 0.090 - ETA: 1:22 - loss: 0.09 - ETA: 1:22 - loss: 0.09 - ETA: 1:22 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0. - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:21 - loss: 0.090 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.09 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.090 - ETA: 1:20 - loss: 0.09 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0. - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0.0 - ETA: 1:19 - loss: 0.090 - ETA: 1:19 - loss: 0 - ETA: 1:18 - loss: 0.09 - ETA: 1:18 - loss: 0. - ETA: 1:18 - loss: 0.0 - ETA: 1:18 - loss: 0.090 - ETA: 1:18 - loss: 0.0 - ETA: 1:17 - loss: 0.0 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0. - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0.090 - ETA: 1:17 - loss: 0.090 - ETA: 1:16 - loss: 0.09 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.09 - ETA: 1:16 - loss: 0.0 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0.09 - ETA: 1:16 - loss: 0.090 - ETA: 1:16 - loss: 0. - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0.09 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss: 0.0 - ETA: 1:15 - loss: 0.090 - ETA: 1:15 - loss - ETA: 1:14 - loss: 0.09 - ETA: 1:14 - loss: 0 - ETA: 1:14 - loss: 0.0 - ETA: 1:14 - loss: - ETA: 1:13 - loss: - ETA: 1:13  - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.090 - ETA: 1:12 - loss: 0.0 - ETA: 1:11 - loss: 0.09 - ETA: 1:11 - loss - ETA: 1:11 - loss: 0.0 - ETA: 1:11 - loss: 0.090 - ETA: 1:11 -  - ETA: 1:10 - loss: 0.09 - ETA: 1:10 - - ETA: 1:10 - loss - ETA: 1:09 - loss: 0.09 - ETA: 1:09 - loss: 0.0 - ETA: 1:09 - loss: 0.090 - ETA: 1:09 - loss: 0. - ETA: 1:08 - loss: 0.09 - ETA: 1:08 - loss: 0.09 - ETA: 1:08 - loss: 0.09 - ETA: 1:08 - loss: 0.090 - ETA: 1:08 - loss: 0.090 - ETA: 1:08 - loss: - ETA: 1:07 - loss: 0.090 - ETA: 1:07 - loss: 0. - ETA: 1:07 - loss: 0.09 - ETA: 1:07 - loss: 0.090 - ETA: 1:07 - loss: 0.09 - ETA: 1:07 - loss: 0.09 - ETA: 1:07 - loss: 0.090 - ETA: 1:06 - loss: 0 - ETA: 1:06 - loss: 0. - ETA: 1:06 - loss: 0.090 - ETA: 1:06 - loss: 0.090 - ETA: 1:06 - loss: 0.090 - ETA: 1:06 - loss: 0.090 - ETA: 1:06 - loss: 0.090 - ETA: 1:06 - loss: 0.090 - ETA: 1:05 - loss: 0.090 - ETA: 1:05 - loss: 0. - ETA: 1:05 - loss: 0.090 - ETA: 1:05 - loss: 0.0 - ETA: 1:05 - loss: 0.09 - ETA: 1:05 - loss: 0 - ETA: 1:05 - loss: - ETA: 1:04 - los - ETA: 1:04 - loss: 0 - ETA: 1:03 - loss: 0.090 - ETA: 1:03 - loss: 0.090 - ETA: 1:03 - loss: 0.090 - ETA: 1:03 - loss: 0.090 - ETA: 1:03 - loss: 0.09 - ETA: 1:03 - loss: 0.090 - ETA: 1:03 - loss: 0.090 - ETA: 1:03 - loss: 0.090 - ETA: 1:03 - loss: 0.09 - ETA: 1:02 - loss: 0.0 - ETA: 1:02 - loss: 0 - ETA: 1:02 - loss: 0.09 - ETA: 1:02 - loss: 0.090 - ETA: 1:02 - loss: 0.090 - ETA: 1:02 - loss: 0.0 - ETA: 1:02 - loss: 0.0 - ETA: 1:01 - loss: 0.09 - ETA: 1:01 - loss: 0. - ETA: 1:01 - loss: 0.0 - ETA: 1:01 - loss: 0.090 - ETA: 1:01 - loss: 0.090 - ETA: 1:01 - loss: 0.090 - ETA: 1:01 - loss: 0.090 - ETA: 1:01 - loss: 0.09 ...

# %%
scores = model.evaluate(x_test, y_test, verbose=0)
scores
# Out:
# 0.08999738842248917

# %%
#  method 3
# Model = Sequential([

#         RNN(50,input_shape=(features,x_train.shape[2]),
#                           activation='sigmoid',recurrent_activation='hard_sigmoid'),
#         keras.layers.Dense(1,activation="softmax")
#     ])

# Model.compile(optimizer='rmsprop',loss='mse', metrics=['accuracy'])

# #Training the model

# Model.fit(x_train, y_train, epochs=10, batch_size= 32) 
# Model.summary()

# # Final evaluation of the model
# scores = Model.evaluate(x_test, y_test, verbose=0)
# print('/n')
# print("Accuracy: %.2f%%" % (scores[1]*100))
